# %%
import pyspark

myConf=pyspark.SparkConf()
spark= pyspark.sql.SparkSession\
    .builder\
    .master('local')\
    .appName('myApp')\
    .config(conf=myConf)\
    .getOrCreate()

# %% [markdown]
# 1) DataFrame을 생성

# %%
import os
fname= os.path.join('data', '제74주년_경찰의_날_기념식_축사.txt')
myDf= spark.read.text(fname)
myDf= myDf.select(myDf['value'].alias('sent'))
myDf.show(4)
# Out:
# +---------------------------------+
# |                             sent|
# +---------------------------------+
# | 존경하는 국민 여러분, 경찰관 ...|
# |                                 |
# |국민의 안전을 위해 밤낮없이 애...|
# |                                 |
# +---------------------------------+
# only showing top 4 rows

# %%
# 공백인 행이 포함되어 있으므로 빈 행을 제거
import pandas as pd
import numpy as np

_myDf= myDf.toPandas()
_myDf['sent'].replace('', np.nan, inplace=True)

# %%
_myDf.dropna(subset=['sent'], inplace=True)

# %%
myDf= spark.createDataFrame(_myDf)

# %%
myDf.show(4)
# Out:
# +----------------------------------+
# |                              sent|
# +----------------------------------+
# |  존경하는 국민 여러분, 경찰관 ...|
# | 국민의 안전을 위해 밤낮없이 애...|
# |오늘 홍조근정훈장을 받으신 중앙...|
# |           사랑하는 경찰관 여러분,|
# +----------------------------------+
# only showing top 4 rows

# %% [markdown]
# 2) 단어로 분리해서, 출력

# %%
from pyspark.ml.feature import RegexTokenizer
regtokenizer= RegexTokenizer(inputCol='sent', outputCol='words', pattern='\\s+')

# %%
tokDf= regtokenizer.transform(myDf)

# %%
tokDf.show(4)
# Out:
# +----------------------------------+--------------------------------+
# |                              sent|                           words|
# +----------------------------------+--------------------------------+
# |  존경하는 국민 여러분, 경찰관 ...|   [존경하는, 국민, 여러분,, ...|
# | 국민의 안전을 위해 밤낮없이 애...|  [국민의, 안전을, 위해, 밤낮...|
# |오늘 홍조근정훈장을 받으신 중앙...|[오늘, 홍조근정훈장을, 받으신...|
# |           사랑하는 경찰관 여러분,|     [사랑하는, 경찰관, 여러분,]|
# +----------------------------------+--------------------------------+
# only showing top 4 rows

# %% [markdown]
#  3) 불용어 구성, 출력

# %%
from pyspark.ml.feature import StopWordsRemover
stopwords=[u'돌', u'참', u'더', u'될', u'그', u'등', u'법', u'큰', u'수'] #'경찰의 날'의 '날'에는 따옴표가 붙어있어 한 글자로 카운트X

# %%
stop= StopWordsRemover(inputCol='words', outputCol='nostops')
stop.setStopWords(stopwords)
# Out:
# StopWordsRemover_9f14a9442964

# %%
for e in stop.getStopWords():
    print(e, end='/')
# Out:
# 돌/참/더/될/그/등/법/큰/수/

# %% [markdown]
# 4) 불용어 제거하고, 출력

# %%
stopDf= stop.transform(tokDf)
for e in stopDf.select('words', 'nostops').take(4):
    print(e)
    print()
# Out:
# Row(words=['존경하는', '국민', '여러분,', '경찰관', '여러분,', '일흔네', '돌', '‘경찰의', '날’입니다.'], nostops=['존경하는', '국민', '여러분,', '경찰관', '여러분,', '일흔네', '‘경찰의', '날’입니다.'])
#
# Row(words=['국민의', '안전을', '위해', '밤낮없이', '애쓰시는', '전국의', '15만', '경찰관', '여러분께', '먼저', '감사를', '드립니다.', '전몰·순직', '경찰관들의', '고귀한', '희생에', '경의를', '표합니다.', '유가족', '여러분께', '위로의', '마음을', '전합니다.'], nostops=['국민의', '안전을', '위해', '밤낮없이', '애쓰시는', '전국의', '15만', '경찰관', '여러분께', '먼저', '감사를', '드립니다.', '전몰·순직', '경찰관들의', '고귀한', '희생에', '경의를', '표합니다.', '유가족', '여러분께', '위로의', '마음을', '전합니다.'])
#
# Row(words=['오늘', '홍조근정훈장을', '받으신', '중앙경찰학교장', '이은정', '치안감님,', '근정포장을', '받으신', '광주남부경찰서', '김동현', '경감님을', '비롯한', '수상자', '여러분께', '각별한', '축하와', '감사를', '드립니다.', '또한', '경찰', '영웅으로', '추서되신', '차일혁,', '최중락님께', '국민의', '사랑을', '전해드립니다.'], nostops=['오늘', '홍조근정훈장을', '받으신', '중앙경찰학교장', '이은정', '치안감님,', '근정포장을', '받으신', '광주남부경찰서', '김동현', '경감님을', '비롯한', '수상자', '여러분께', '각별한', '축하와', '감사를', '드립니다.', '또한', '경찰', '영웅으로', '추서되신', '차일혁,', '최중락님께', '국민의', '사랑을', '전해드립니다.'])
#
# Row(words=['사랑하는', '경찰관', '여러분,'], nostops=['사랑하는', '경찰관', '여러분,'])

# %% [markdown]
# 5) TF-IDF를 계산하고, 출력

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer=TfidfVectorizer(stop_words=stopwords, norm=None)

# %%
doc= myDf.rdd.flatMap(lambda line: line).collect()

# %%
vectorizer.fit_transform(doc)
# Out:
# <21x347 sparse matrix of type '<class 'numpy.float64'>'
# 	with 404 stored elements in Compressed Sparse Row format>

# %%
doc_tf= vectorizer.vocabulary_
print(doc_tf)
# Out:
# {'존경하는': 278, '국민': 80, '여러분': 212, '경찰관': 45, '일흔네': 251, '경찰의': 53, '입니다': 257, '국민의': 84, '안전을': 201, '위해': 232, '밤낮없이': 165, '애쓰시는': 206, '전국의': 266, '15만': 1, '여러분께': 213, '먼저': 144, '감사를': 15, '드립니다': 134, '전몰': 267, '순직': 194, '경찰관들의': 46, '고귀한': 59, '희생에': 346, '경의를': 42, '표합니다': 325, '유가족': 233, '위로의': 228, '마음을': 139, '전합니다': 270, '오늘': 220, '홍조근정훈장을': 340, '받으신': 159, '중앙경찰학교장': 290, '이은정': 243, '치안감님': 315, '근정포장을': 96, '광주남부경찰서': 75, '김동현': 103, '경감님을': 38, '비롯한': 175, '수상자': 192, '각별한': 14, '축하와': 309, '또한': 137, '경찰': 43, '영웅으로': 219, '추서되신': 308, '차일혁': 300, '최중락님께': 307, '사랑을': 178, '전해드립니다': 271, '사랑하는': 179, '여러분의': 215, '헌신적': 338, '노력으로': 112, '우리의': 227, '치안은': 317, '좋아졌습니다': 280, '지난해': 292, '범죄': 167, '발생은': 161, '2015년에': 5, '비해': 176, '15': 0, '줄었습니다': 288, '같은': 21, '기간': 97, '교통사고': 76, '사망자는': 180, '18': 2, '감소했습니다': 18, '치안의': 319, '개선은': 23, '체감으로': 304, '나타나고': 108, '있습니다': 259, '올해': 221, '상반기': 182, '체감안전도는': 303, '74': 9, '5점으로': 8, '역대': 216, '최고를': 306, '기록했습니다': 99, '범죄안전도는': 168, '처음으로': 302, '80점을': 11, '넘었습니다': 111, '한국을': 327, '찾는': 301, '외국': 224, '관광객들도': 71, '치안을': 318, '가장': 13, '좋게': 279, '평가합니다': 323, '한국의': 328, '무엇이': 151, '좋았느냐는': 281, '물음에': 153, '관광객들은': 72, '7년': 10, '연속으로': 217, '치안이': 320, '좋았다고': 282, '응답했습니다': 235, '개발도상국들은': 22, '경찰을': 52, '모범으로': 146, '삼으려': 181, '합니다': 332, '올해는': 222, '맞춰': 142, '국제치안산업박람회와': 86, '서울국제경찰청장회의가': 183, '함께': 330, '열립니다': 218, '치안': 314, '발전과': 162, '치안산업': 316, '발전이': 163, '세계에': 186, '널리': 110, '알려지게': 203, '것입니다': 36, '자랑스러운': 260, '경찰헌장은': 57, '나라와': 104, '겨레를': 37, '위하여': 230, '충성': 310, '다한다는': 121, '다짐으로': 119, '시작합니다': 198, '헌장처럼': 339, '우리': 226, '경찰은': 51, '위한': 231, '길을': 101, '걸으려': 31, '노력해': 114, '왔습니다': 223, '대한민국': 123, '1945년': 3, '광복': 74, '직후에': 295, '공식': 63, '탄생했습니다': 321, '그러나': 90, '뿌리는': 177, '임시정부에': 255, '닿아': 122, '임시정부': 254, '초대': 305, '경무국장': 39, '백범': 166, '김구': 102, '선생과': 184, '나석주': 105, '나창헌': 107, '유상근': 234, '의사': 239, '앞장서서': 205, '일제와': 250, '싸웠습니다': 199, '일본': 248, '관헌에게': 73, '폭탄을': 324, '던지고': 126, '밀정을': 156, '응징하며': 237, '임정': 256, '요인들을': 225, '보호했습니다': 171, '이후': 244, '25전쟁에서도': 6, '국군과': 79, '피를': 326, '흘렸습니다': 345, '전쟁에서': 269, '1만여': 4, '명의': 145, '경찰관이': 47, '목숨을': 147, '잃었습니다': 252, '후로도': 342, '지키고': 293, '국가의': 78, '안보를': 200, '도왔습니다': 127, '헌신에': 337, '대해': 124, '국민과': 81, '거듭': 28, '감사의': 16, '말씀을': 141, '감사합니다': 17, '잘못도': 263, '없지는': 211, '않았습니다': 202, '한때': 329, '공권력을': 61, '무리하게': 150, '집행하며': 298, '인권을': 245, '훼손했습니다': 343, '부실하거나': 173, '불공정한': 174, '수사로': 191, '지탄을': 294, '받은': 160, '적도': 265, '무기력한': 149, '집행으로': 297, '국민께': 82, '걱정을': 30, '드리기도': 133, '했습니다': 333, '지금': 291, '과거를': 68, '돌아보며': 129, '국가에': 77, '충성하는': 311, '경찰로': 49, '거듭나려고': 29, '노력하고': 113, '문재인': 152, '정부': 273, '들어': 135, '개혁위원회를': 26, '만들고': 140, '자체개혁에': 261, '나섰습니다': 106, '개혁을': 27, '국민은': 83, '기대로': 98, '주목하고': 284, '검경': 32, '수사권': 190, '조정과': 277, '자치경찰제': 262, '도입이': 128, '국회에서': 88, '논의되고': 115, '국회가': 87, '조속히': 276, '입법을': 258, '매듭지어': 143, '주시기': 285, '바랍니다': 157, '그리하여': 93, '경찰이': 54, '중립성': 289, '공정성': 64, '전문성을': 268, '갖추고': 20, '본연의': 172, '임무를': 253, '충실히': 312, '수행하는': 193, '선진경찰로': 185, '더욱': 125, '발전해': 164, '주기를': 283, '소망합니다': 187, '정부는': 274, '근무여건을': 94, '개선하기': 25, '이미': 241, '572명을': 7, '늘렸고': 118, '앞으로도': 204, '충원을': 313, '계속할': 58, '특히': 322, '일선': 249, '근무환경을': 95, '개선하겠습니다': 24, '누구도': 116, '위에': 229, '군림하지': 89, '못하는': 148, '법치주의를': 170, '확립하고자': 341, '그러자면': 91, '검찰과': 34, '법을': 169, '누구에게나': 117, '엄정하고': 208, '공정하게': 65, '집행해야': 299, '됩니다': 132, '수사': 189, '공정해야': 67, '동시에': 130, '스스로도': 195, '엄격히': 207, '준수해야': 287, '공권력이': 62, '인권의': 246, '제약을': 275, '수반하는': 188, '경우에는': 40, '절제하며': 272, '행사하는': 335, '것이': 35, '마땅합니다': 138, '검찰개혁과': 33, '경찰개혁은': 44, '미룰': 154, '없는': 209, '시대적': 196, '과제가': 69, '됐습니다': 131, '따뜻한': 136, '의로운': 238, '공정한': 66, '다짐합니다': 120, '흔들림': 344, '없이': 210, '길로': 100, '가시기': 12, '국민이': 85, '여러분을': 214, '응원할': 236, '행사를': 334, '준비하신': 286, '민갑룡': 155, ...

# %%
doc_idf= vectorizer.idf_
print(doc_idf)
# Out:
# [3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 2.99243016 3.39789527 2.99243016 3.39789527 2.99243016
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  2.70474809 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 2.70474809 3.39789527 2.29928298 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 2.1451323  2.99243016 2.29928298
#  2.99243016 3.39789527 3.39789527 2.99243016 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 2.99243016 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 2.99243016 3.39789527 3.39789527
#  2.29928298 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  2.99243016 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 2.99243016
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 2.70474809 3.39789527 3.39789527 2.99243016
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  2.99243016 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 2.99243016 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 2.99243016 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 2.99243016 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 2.48160454 2.99243016 3.39789527 3.39789527
#  2.70474809 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 2.99243016 2.70474809
#  3.39789527 3.39789527 3.39789527 3.39789527 2.99243016 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 2.1451323  3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 2.99243016 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 2.99243016 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  2.99243016 3.39789527 2.99243016 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527 3.39789527
#  3.39789527 3.39789527 3.39789527 3.39789527 3.39789527]

# %% [markdown]
# 6) TF-IDF 컬럼을 features로 구성, 출력

# %%
import pandas as pd
idfDf= pd.DataFrame(list(doc_tf.items()), columns=['word', 'ID'])

# %%
idfDf=idfDf.assign(idf=doc_idf)

# %%
df6= spark.createDataFrame(idfDf)

# %%
df6.show(4)
# Out:
# +--------+---+------------------+
# |    word| ID|               idf|
# +--------+---+------------------+
# |존경하는|278|3.3978952727983707|
# |    국민| 80|3.3978952727983707|
# |  여러분|212|3.3978952727983707|
# |  경찰관| 45|3.3978952727983707|
# +--------+---+------------------+
# only showing top 4 rows
